# %% [markdown]
# <a href="https://colab.research.google.com/github/itslucky07/CODSOFT/blob/main/recursion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # Sum of digit

# %% [markdown]
# # sum of digit

# %%
def sumOfDigit(n):
  assert n >= 0 and int(n) == n, "The number must be positive integer only"
  if n == 0:
    return 0
  return int(n%10) + sumOfDigit(int(n/10))
print(sumOfDigit(53125))
# Out:
# 16

# %% [markdown]
# # power of number

# %%
def power(base,exp):
  assert exp >= 0 and int(exp) == exp, "The number must be positive integer only"
  if exp ==0:
    return 1
  if exp == 1:
    return base
  return base*power(base,exp-1)

power(2.5,4)
# Out:
# 39.0625

# %% [markdown]
# # to find thhe gcd (greatest common divisor)  or hcf

# %%
def gcd(a,b):
  assert int(a) == a and int(b) == b, "The number must be positive integer only"
  if a < 0:
    a = -1 * a
  if b < 0:
    b = -1 * b

  if b == 0:
    return a
  else:
    return gcd(b, a%b)

print(gcd(48,18))
# Out:
# 6

# %% [markdown]
# # Decimal to binary
#
#
# divide the number by 2.
#
# get the integer quotient for the binary digit.
#
# get the remainder for the binary digit
#
# repeart the steps until the quotient is equal to zero .
#   f

# %%
def decimalToBinary(n):
  assert int(n) == n, "The number must be positive integer only"
  if n == 0:
    return 0
  else:
    return n%2 + 10*decimalToBinary(int(n/2))

print(decimalToBinary(13))
# Out:
# 1101
